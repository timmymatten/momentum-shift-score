# %%
from pybaseball import statcast

# %%
alonso_williams_data = statcast('2024-10-03', team='NYM')
alonso_williams_data
# Out:
# This is a large query, it may take a moment to complete
# /opt/anaconda3/envs/baseball/lib/python3.12/site-packages/pybaseball/datahelpers/postprocessing.py:59: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   data_copy[column] = data_copy[column].apply(pd.to_datetime, errors='ignore', format=date_format)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  7.06it/s]
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 123         SI 2024-10-03           93.9           1.97           5.93
# 125         FF 2024-10-03           93.8           2.17           5.85
# 130         FF 2024-10-03           96.5           2.15           5.89
# 136         CH 2024-10-03           86.7            1.8           6.02
# 138         FF 2024-10-03           92.9           2.32           5.88
# ...
